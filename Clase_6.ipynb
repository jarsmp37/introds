# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/jarsmp37/introds/main/Churn_Bank.csv')
df
# Out:
#       RowNumber  CustomerId   Surname CreditScore      Geography  Gender  \
# 0           1.0  15634602.0  Hargrave         619         France  Female
# 1           2.0  15647311.0      Hill         608          Spain  Female
# 2           3.0  15619304.0      Onio         502         France  Female
# 3           4.0  15701354.0      Boni         699         France  Female
# 4           5.0  15737888.0  Mitchell         850          Spain  Female
# ...         ...         ...       ...         ...            ...     ...
# 12200    7026.0  15711446.0  Sinclair         569          Spain  Female
# 12201    1272.0  15793854.0     Ahmed         723         France    Male
# 12202    4942.0  15715047.0    Joshua         640  invalid_value    Male
# 12203    8299.0  15605534.0  Turnbull         644        Germany  Female
# 12204    1689.0  15804610.0    Valdez         601         France  Female
#
#         Age Tenure    Balance NumOfProducts HasCrCard IsActiveMember  \
# ...

# %% [markdown]
# Limpiando los nan

# %%
df.isnull().sum()
# Out:
# RowNumber             136
# CustomerId            155
# Surname               122
# CreditScore           125
# Geography             129
# Gender                136
# Age                   148
# Tenure                126
# Balance               140
# NumOfProducts         120
# HasCrCard             153
# IsActiveMember        129
# EstimatedSalary       144
# Exited                140
# Complain              145
# Satisfaction Score    145
# Card Type             169
# Point Earned          126
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# RowNumber             0
# CustomerId            0
# Surname               0
# CreditScore           0
# Geography             0
# Gender                0
# Age                   0
# Tenure                0
# Balance               0
# NumOfProducts         0
# HasCrCard             0
# IsActiveMember        0
# EstimatedSalary       0
# Exited                0
# Complain              0
# Satisfaction Score    0
# Card Type             0
# Point Earned          0
# dtype: int64

# %%
df
# Out:
#       RowNumber  CustomerId   Surname CreditScore      Geography  Gender  \
# 1           2.0  15647311.0      Hill         608          Spain  Female
# 3           4.0  15701354.0      Boni         699         France  Female
# 5           6.0  15574012.0       Chu         645          Spain    Male
# 6           7.0  15592531.0  Bartlett         822         France    Male
# 7           8.0  15656148.0    Obinna         376        Germany  Female
# ...         ...         ...       ...         ...            ...     ...
# 12199    2271.0  15622217.0        Tu         538         France  Female
# 12201    1272.0  15793854.0     Ahmed         723         France    Male
# 12202    4942.0  15715047.0    Joshua         640  invalid_value    Male
# 12203    8299.0  15605534.0  Turnbull         644        Germany  Female
# 12204    1689.0  15804610.0    Valdez         601         France  Female
#
#         Age Tenure    Balance NumOfProducts HasCrCard IsActiveMember  \
# ...

# %% [markdown]
# Eliminando el texto invalid_value

# %%
lista_col=df.columns
for i in lista_col:
    print(f"En la columna {i} los invalid_value son: {df[df[i] == 'invalid_value'].shape[0]}")
# Out:
# En la columna RowNumber los invalid_value son: 111
# En la columna CustomerId los invalid_value son: 116
# En la columna Surname los invalid_value son: 100
# En la columna CreditScore los invalid_value son: 100
# En la columna Geography los invalid_value son: 111
# En la columna Gender los invalid_value son: 88
# En la columna Age los invalid_value son: 97
# En la columna Tenure los invalid_value son: 123
# En la columna Balance los invalid_value son: 129
# En la columna NumOfProducts los invalid_value son: 130
# En la columna HasCrCard los invalid_value son: 115
# En la columna IsActiveMember los invalid_value son: 103
# En la columna EstimatedSalary los invalid_value son: 131
# En la columna Exited los invalid_value son: 119
# En la columna Complain los invalid_value son: 134
# En la columna Satisfaction Score los invalid_value son: 130
# En la columna Card Type los invalid_value son: 118
# En la columna Point Earned los invalid_value son: 120

# %%
for i in lista_col:
    df=df[df[i] != 'invalid_value']
df
# Out:
#       RowNumber  CustomerId   Surname CreditScore Geography  Gender   Age  \
# 1           2.0  15647311.0      Hill         608     Spain  Female  41.0
# 5           6.0  15574012.0       Chu         645     Spain    Male  44.0
# 6           7.0  15592531.0  Bartlett         822    France    Male  50.0
# 7           8.0  15656148.0    Obinna         376   Germany  Female  29.0
# 8           9.0  15792365.0        He         501    France    Male  44.0
# ...         ...         ...       ...         ...       ...     ...   ...
# 12198    6261.0  15672826.0      Chen         666    France  Female  32.0
# 12199    2271.0  15622217.0        Tu         538    France  Female  38.0
# 12201    1272.0  15793854.0     Ahmed         723    France    Male  42.0
# 12203    8299.0  15605534.0  Turnbull         644   Germany  Female  51.0
# 12204    1689.0  15804610.0    Valdez         601    France  Female  41.0
#
#       Tenure    Balance NumOfProducts HasCrCard IsActiveMember  \
# ...

# %% [markdown]
# Quitar los valores repetidos de la columna CustomerId

# %%
df=df.drop_duplicates(subset=['CustomerId'])
df
# Out:
#       RowNumber  CustomerId    Surname CreditScore Geography  Gender   Age  \
# 1           2.0  15647311.0       Hill         608     Spain  Female  41.0
# 5           6.0  15574012.0        Chu         645     Spain    Male  44.0
# 6           7.0  15592531.0   Bartlett         822    France    Male  50.0
# 7           8.0  15656148.0     Obinna         376   Germany  Female  29.0
# 8           9.0  15792365.0         He         501    France    Male  44.0
# ...         ...         ...        ...         ...       ...     ...   ...
# 11915     479.0  15677538.0    Nwokike         569    France    Male  38.0
# 11920     618.0  15766575.0  Larionova         612   Germany  Female  62.0
# 11991    7229.0  15707602.0    Macleod         539    France  Female  47.0
# 12088    9435.0  15733229.0  Rodriguez         638     Spain  Female  34.0
# 12167    9945.0  15703923.0    Cameron         744   Germany    Male  41.0
#
#       Tenure    Balance NumOfProducts HasCrCard IsActiveMember  \
# ...

# %% [markdown]
# Renombrando los nombres de las columnas al español

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited', 'Complain',
#        'Satisfaction Score', 'Card Type', 'Point Earned'],
#       dtype='object')

# %% [markdown]
# estoy cambiando nombres

# %%
df=df.rename(columns={'Surname': 'Apellido','Geography': 'Pais','Gender':'Genero','Age':'Edad',
                      'Tenure':'Estadia', 'NumOfProducts':'#Prod','HasCrCard':'TarjetaCredito',
                      'IsActiveMember':'Activo','EstimatedSalary':'Salario','Exited':'Salida',
                      'Complain':'Quejas','Satisfaction Score':'Nivel_satisf',
                      'Card Type':'Tipo_tarjeta','Point Earned':'Puntos'})
df
# Out:
#       RowNumber  CustomerId   Apellido CreditScore     Pais  Genero  Edad  \
# 1           2.0  15647311.0       Hill         608    Spain  Female  41.0
# 5           6.0  15574012.0        Chu         645    Spain    Male  44.0
# 6           7.0  15592531.0   Bartlett         822   France    Male  50.0
# 7           8.0  15656148.0     Obinna         376  Germany  Female  29.0
# 8           9.0  15792365.0         He         501   France    Male  44.0
# ...         ...         ...        ...         ...      ...     ...   ...
# 11915     479.0  15677538.0    Nwokike         569   France    Male  38.0
# 11920     618.0  15766575.0  Larionova         612  Germany  Female  62.0
# 11991    7229.0  15707602.0    Macleod         539   France  Female  47.0
# 12088    9435.0  15733229.0  Rodriguez         638    Spain  Female  34.0
# 12167    9945.0  15703923.0    Cameron         744  Germany    Male  41.0
#
#       Estadia    Balance #Prod TarjetaCredito Activo    Salario Salida Quejas  \
# ...

# %% [markdown]
# Quitamos la primera columna Row number

# %%
df=df.drop(columns=['RowNumber'])

# %%
df
# Out:
#        CustomerId   Apellido CreditScore     Pais  Genero  Edad Estadia  \
# 1      15647311.0       Hill         608    Spain  Female  41.0       1
# 5      15574012.0        Chu         645    Spain    Male  44.0       8
# 6      15592531.0   Bartlett         822   France    Male  50.0       7
# 7      15656148.0     Obinna         376  Germany  Female  29.0       4
# 8      15792365.0         He         501   France    Male  44.0       4
# ...           ...        ...         ...      ...     ...   ...     ...
# 11915  15677538.0    Nwokike         569   France    Male  38.0       7
# 11920  15766575.0  Larionova         612  Germany  Female  62.0       8
# 11991  15707602.0    Macleod         539   France  Female  47.0       2
# 12088  15733229.0  Rodriguez         638    Spain  Female  34.0       7
# 12167  15703923.0    Cameron         744  Germany    Male  41.0       7
#
#          Balance #Prod TarjetaCredito Activo    Salario Salida Quejas  \
# ...

# %% [markdown]
# Reindexación

# %%
df = df.reset_index(drop=True)
df
# Out:
#       CustomerId   Apellido CreditScore     Pais  Genero  Edad Estadia  \
# 0     15647311.0       Hill         608    Spain  Female  41.0       1
# 1     15574012.0        Chu         645    Spain    Male  44.0       8
# 2     15592531.0   Bartlett         822   France    Male  50.0       7
# 3     15656148.0     Obinna         376  Germany  Female  29.0       4
# 4     15792365.0         He         501   France    Male  44.0       4
# ...          ...        ...         ...      ...     ...   ...     ...
# 6659  15677538.0    Nwokike         569   France    Male  38.0       7
# 6660  15766575.0  Larionova         612  Germany  Female  62.0       8
# 6661  15707602.0    Macleod         539   France  Female  47.0       2
# 6662  15733229.0  Rodriguez         638    Spain  Female  34.0       7
# 6663  15703923.0    Cameron         744  Germany    Male  41.0       7
#
#         Balance #Prod TarjetaCredito Activo    Salario Salida Quejas  \
# ...

# %% [markdown]
# Cambiando los tipos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6664 entries, 0 to 6663
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerId      6664 non-null   object
#  1   Apellido        6664 non-null   object
#  2   CreditScore     6664 non-null   object
#  3   Pais            6664 non-null   object
#  4   Genero          6664 non-null   object
#  5   Edad            6664 non-null   object
#  6   Estadia         6664 non-null   object
#  7   Balance         6664 non-null   object
#  8   #Prod           6664 non-null   object
#  9   TarjetaCredito  6664 non-null   object
#  10  Activo          6664 non-null   object
#  11  Salario         6664 non-null   object
#  12  Salida          6664 non-null   object
#  13  Quejas          6664 non-null   object
#  14  Nivel_satisf    6664 non-null   object
#  15  Tipo_tarjeta    6664 non-null   object
#  16  Puntos          6664 non-null   object
# ...

# %%
df.head(3)
# Out:
#    CustomerId  Apellido CreditScore    Pais  Genero  Edad Estadia    Balance  \
# 0  15647311.0      Hill         608   Spain  Female  41.0       1   83807.86
# 1  15574012.0       Chu         645   Spain    Male  44.0       8  113755.78
# 2  15592531.0  Bartlett         822  France    Male  50.0       7        0.0
#
#   #Prod TarjetaCredito Activo    Salario Salida Quejas Nivel_satisf  \
# 0   1.0              0      1  112542.58      0      1            3
# 1   2.0              1      0  149756.71      1      1            5
# 2   2.0              1      1    10062.8      0      0            2
#
#   Tipo_tarjeta Puntos
# 0      DIAMOND    456
# 1      DIAMOND    484
# 2       SILVER    206

# %%
#Primero lo pasamos a float y despues a int en caso de dar error
df['CustomerId']=df['CustomerId'].astype(float)
df['CustomerId']=df['CustomerId'].astype(int)
df['CreditScore']=df['CreditScore'].astype(int)
df['Edad']=df['Edad'].astype(float)
df['Edad']=df['Edad'].astype(int)
df['Estadia']=df['Estadia'].astype(int)
df['Balance']=df['Balance'].astype(float)
df['Edad']=df['Edad'].astype(float)
df['Edad']=df['Edad'].astype(int)

# %%
df.columns
# Out:
# Index(['CustomerId', 'Apellido', 'CreditScore', 'Pais', 'Genero', 'Edad',
#        'Estadia', 'Balance', '#Prod', 'TarjetaCredito', 'Activo', 'Salario',
#        'Salida', 'Quejas', 'Nivel_satisf', 'Tipo_tarjeta', 'Puntos'],
#       dtype='object')

# %%
#Lista de columnas a int
int_col=['CustomerId', 'CreditScore', 'Edad',
       'Estadia', '#Prod', 'TarjetaCredito', 'Activo',
       'Salida', 'Quejas', 'Nivel_satisf', 'Puntos']

for i in int_col:
    df[i]=df[i].astype(float)
    df[i]=df[i].astype(int)

# %%
df['Salario']=df['Salario'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6664 entries, 0 to 6663
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerId      6664 non-null   int64
#  1   Apellido        6664 non-null   object
#  2   CreditScore     6664 non-null   int64
#  3   Pais            6664 non-null   object
#  4   Genero          6664 non-null   object
#  5   Edad            6664 non-null   int64
#  6   Estadia         6664 non-null   int64
#  7   Balance         6664 non-null   float64
#  8   #Prod           6664 non-null   int64
#  9   TarjetaCredito  6664 non-null   int64
#  10  Activo          6664 non-null   int64
#  11  Salario         6664 non-null   float64
#  12  Salida          6664 non-null   int64
#  13  Quejas          6664 non-null   int64
#  14  Nivel_satisf    6664 non-null   int64
#  15  Tipo_tarjeta    6664 non-null   object
#  16  Puntos          6664 non-null   int64
# ...

# %%
df['Pais'].unique()
# Out:
# array(['Spain', 'France', 'Germany'], dtype=object)

# %%
df['Genero'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
#diccionario general
dic={'Spain':'España', 'France':'Francia', 'Germany':'Alemania','Female':'Mujer','Male':'Hombre'}

# %%
df['Pais'] = df['Pais'].replace(dic)
df
# Out:
#       CustomerId   Apellido  CreditScore      Pais  Genero  Edad  Estadia  \
# 0       15647311       Hill          608    España  Female    41        1
# 1       15574012        Chu          645    España    Male    44        8
# 2       15592531   Bartlett          822   Francia    Male    50        7
# 3       15656148     Obinna          376  Alemania  Female    29        4
# 4       15792365         He          501   Francia    Male    44        4
# ...          ...        ...          ...       ...     ...   ...      ...
# 6659    15677538    Nwokike          569   Francia    Male    38        7
# 6660    15766575  Larionova          612  Alemania  Female    62        8
# 6661    15707602    Macleod          539   Francia  Female    47        2
# 6662    15733229  Rodriguez          638    España  Female    34        7
# 6663    15703923    Cameron          744  Alemania    Male    41        7
#
#         Balance  #Prod  TarjetaCredito  Activo    Salario  Salida  Quejas  \
# ...

# %%
df['Genero'] = df['Genero'].replace(dic)
df
# Out:
#       CustomerId   Apellido  CreditScore      Pais  Genero  Edad  Estadia  \
# 0       15647311       Hill          608    España   Mujer    41        1
# 1       15574012        Chu          645    España  Hombre    44        8
# 2       15592531   Bartlett          822   Francia  Hombre    50        7
# 3       15656148     Obinna          376  Alemania   Mujer    29        4
# 4       15792365         He          501   Francia  Hombre    44        4
# ...          ...        ...          ...       ...     ...   ...      ...
# 6659    15677538    Nwokike          569   Francia  Hombre    38        7
# 6660    15766575  Larionova          612  Alemania   Mujer    62        8
# 6661    15707602    Macleod          539   Francia   Mujer    47        2
# 6662    15733229  Rodriguez          638    España   Mujer    34        7
# 6663    15703923    Cameron          744  Alemania  Hombre    41        7
#
#         Balance  #Prod  TarjetaCredito  Activo    Salario  Salida  Quejas  \
# ...

# %%
#Guardar los resultados en un csv
df.to_csv("Base_limpia.csv", index=True)
