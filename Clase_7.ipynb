# %% [markdown]
# Instalar librerias
#
# pip install matplotlib
#
# pip install numpy
#
# pip install seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt  # Librería para crear gráficos
import numpy as np  # Librería para generar datos numéricos, aquí la usamos para generar datos aleatorios

# %%
df=pd.read_csv('https://raw.githubusercontent.com/Dannap7337/Pato/main/Base_limpiaclase.csv')
df
# Out:
#       Unnamed: 0  CustomerId   Apellido  CreditScore      Pais  Genero  Edad  \
# 0              0    15647311       Hill          608    España   Mujer    41
# 1              1    15574012        Chu          645    España  Hombre    44
# 2              2    15592531   Bartlett          822   Francia  Hombre    50
# 3              3    15656148     Obinna          376  Alemania   Mujer    29
# 4              4    15792365         He          501   Francia  Hombre    44
# ...          ...         ...        ...          ...       ...     ...   ...
# 6659        6659    15677538    Nwokike          569   Francia  Hombre    38
# 6660        6660    15766575  Larionova          612  Alemania   Mujer    62
# 6661        6661    15707602    Macleod          539   Francia   Mujer    47
# 6662        6662    15733229  Rodriguez          638    España   Mujer    34
# 6663        6663    15703923    Cameron          744  Alemania  Hombre    41
#
# ...

# %% [markdown]
# Descripción de los datos estadísticos

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'CustomerId', 'Apellido', 'CreditScore', 'Pais', 'Genero',
#        'Edad', 'Estadia', 'Balance', '#Prod', 'TarjetaCredito', 'Activo',
#        'Salario', 'Salida', 'Quejas', 'Nivel_satisf', 'Tipo_tarjeta',
#        'Puntos'],
#       dtype='object')

# %%
df.describe()
# Out:
#         Unnamed: 0    CustomerId  CreditScore         Edad      Estadia  \
# count  6664.000000  6.664000e+03  6664.000000  6664.000000  6664.000000
# mean   3331.500000  1.569064e+07   648.655462    39.023109     5.019808
# std    1923.875429  7.225874e+04    97.007889    10.632274     2.878483
# min       0.000000  1.556570e+07   350.000000    18.000000     0.000000
# 25%    1665.750000  1.562769e+07   583.000000    32.000000     3.000000
# 50%    3331.500000  1.569139e+07   650.000000    37.000000     5.000000
# 75%    4997.250000  1.575310e+07   716.000000    44.000000     7.000000
# max    6663.000000  1.581569e+07   850.000000    92.000000    10.000000
#
#              Balance        #Prod  TarjetaCredito       Activo        Salario  \
# count    6664.000000  6664.000000     6664.000000  6664.000000    6664.000000
# mean    76643.480269     1.526711        0.705432     0.509004   99686.699835
# std     62315.963784     0.578421        0.455882     0.499956   57689.084578
# ...

# %% [markdown]
# plt.figure(figsize=(8, 6)): Define el tamaño del gráfico (ancho y alto) en pulgadas.
#
# plt.hist(data, bins=30, color='blue', edgecolor='black'):
#
# data: Los datos que serán usados para crear el histograma.
#
# bins=30: Número de intervalos (bins) en los que se dividirán los datos. Cuantos más bins, más detallada será la representación.
#
# color='blue': El color de las barras del histograma.
#
# edgecolor='black': El color de los bordes de las barras, que ayuda a diferenciarlas visualmente.

# %%
# Crear el histograma
plt.figure(figsize=(8, 6))  # Define el tamaño del gráfico
plt.hist(df['Edad'], bins=10, color="#59C715", edgecolor='black');  # Datos y configuración del histograma
plt.show()

# %% [markdown]
# Descripción:
#
# plt.title(): Establece el título del gráfico.
#
# plt.xlabel(): Etiqueta para el eje X, que en este caso representa los valores de los datos.
#
# plt.ylabel(): Etiqueta para el eje Y, que representa la frecuencia con que los valores caen en cada bin.

# %%
# Crear el histograma
plt.figure(figsize=(4, 3))  # Define el tamaño del gráfico
plt.hist(df['Edad'], bins=30, color='blue', edgecolor='black');  # Datos y configuración del histograma
#Personalizar
plt.title('Histograma de las edades', fontsize=16)  # Título del gráfico
plt.xlabel('Edades', fontsize=12)  # Etiqueta del eje x
plt.ylabel('Frecuencia', fontsize=12)  # Etiqueta del eje y

plt.show()

# %%
lista=df.columns
for i in lista:
    plt.figure(figsize=(4, 3))  # Define el tamaño del gráfico
    plt.hist(df[i], bins=10, color="#59C715", edgecolor='black');  # Datos y configuración del histograma
    plt.title(f'Histograma de {i}', fontsize=16)
    plt.show()

# %%
plt.figure(figsize=(8, 6))  # Define el tamaño del gráfico
plt.hist(df['Edad'], bins=10, color="#59C715", edgecolor='black');  # Datos y configuración del histograma
plt.show()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'CustomerId', 'Apellido', 'CreditScore', 'Pais', 'Genero',
#        'Edad', 'Estadia', 'Balance', '#Prod', 'TarjetaCredito', 'Activo',
#        'Salario', 'Salida', 'Quejas', 'Nivel_satisf', 'Tipo_tarjeta',
#        'Puntos'],
#       dtype='object')

# %%
# Crear el histograma
plt.figure(figsize=(8, 3))  # Define el tamaño del gráfico
plt.hist(df['Nivel_satisf'], bins=5, color='blue', edgecolor='white');  # Datos y configuración del histograma
#Personalizar
plt.title('Nivel_satisf', fontsize=16)  # Título del gráfico
plt.xlabel('Quejas', fontsize=12)  # Etiqueta del eje x
plt.ylabel('Frecuencia', fontsize=12)  # Etiqueta del eje y

plt.show()

# %%
# Crear el histograma
plt.figure(figsize=(8, 3))  # Define el tamaño del gráfico
plt.hist(df['Apellido'], bins=30, color='blue', edgecolor='black');  # Datos y configuración del histograma
#Personalizar
plt.title('Histograma de las Apellido', fontsize=16)  # Título del gráfico
plt.xlabel('Apellido', fontsize=8)  # Etiqueta del eje x
plt.ylabel('Frecuencia', fontsize=12)  # Etiqueta del eje y

plt.show()

# %%
df=df.drop(columns=['Unnamed: 0'])

# %% [markdown]
# # Boxplot (Diagrama de Caja)
#
# Un **boxplot** (o diagrama de caja) es una herramienta de visualización que resume un conjunto de datos mostrando su distribución a través de cinco números clave:
#
# 1. **Mínimo**: El valor más pequeño (excluyendo valores atípicos).
# 2. **Primer cuartil (Q1)**: El 25% de los datos están por debajo de este valor.
# 3. **Mediana (Q2)**: El valor que separa la mitad superior de la mitad inferior de los datos.
# 4. **Tercer cuartil (Q3)**: El 75% de los datos están por debajo de este valor.
# 5. **Máximo**: El valor más grande (excluyendo valores atípicos).
#
# Además, un **boxplot** también puede mostrar los valores atípicos (outliers), que son puntos de datos que están considerablemente por encima o por debajo del rango intercuartil (IQR).
#
# ## Componentes del Boxplot:
# - **Caja**: Representa el rango entre el primer cuartil (Q1) y el tercer cuartil (Q3).
# - **Línea dentro de la caja**: Representa la mediana (Q2).
# - **Bigotes**: Muestran la variabilidad de los datos fuera de los cuartiles, extendiéndose hasta 1.5 veces el IQR.
# - **Puntos fuera de los bigotes**: Son valores atípicos.
#
# ### Ejemplo de un Boxplot
# El siguiente código crea un boxplot con datos generados aleatoriamente:

# %%
# Crear el boxplot
plt.figure(figsize=(3, 6))
plt.boxplot(df['Edad'], patch_artist=True, notch=True, boxprops=dict(facecolor='lightblue', color='blue'))

# Personalizar el gráfico
plt.title('Boxplot de edad', fontsize=16)
plt.ylabel('Valores', fontsize=12)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# plt.boxplot(): Crea el gráfico de boxplot.
#
# patch_artist=True: Rellena la caja con color.
#
# notch=True: Añade una muesca que muestra una aproximación visual del intervalo de confianza para la mediana.
#
# boxprops: Personaliza el color y la apariencia de la caja.

# %%
# Crear el boxplot
plt.figure(figsize=(8, 3))
plt.boxplot(df['Edad'], patch_artist=True, notch=True, boxprops=dict(facecolor='lightblue', color='blue'), vert=False)

# Personalizar el gráfico
plt.title('Boxplot de edad', fontsize=16)
plt.ylabel('Valores', fontsize=12)

# Mostrar el gráfico
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6664 entries, 0 to 6663
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      6664 non-null   int64
#  1   CustomerId      6664 non-null   int64
#  2   Apellido        6664 non-null   object
#  3   CreditScore     6664 non-null   int64
#  4   Pais            6664 non-null   object
#  5   Genero          6664 non-null   object
#  6   Edad            6664 non-null   int64
#  7   Estadia         6664 non-null   int64
#  8   Balance         6664 non-null   float64
#  9   #Prod           6664 non-null   int64
#  10  TarjetaCredito  6664 non-null   int64
#  11  Activo          6664 non-null   int64
#  12  Salario         6664 non-null   float64
#  13  Salida          6664 non-null   int64
#  14  Quejas          6664 non-null   int64
#  15  Nivel_satisf    6664 non-null   int64
#  16  Tipo_tarjeta    6664 non-null   object
# ...

# %%
lista=['CustomerId', 'CreditScore', 
       'Edad', 'Estadia', 'Balance', '#Prod', 'TarjetaCredito', 'Activo',
       'Salario', 'Salida', 'Quejas', 'Nivel_satisf', 
       'Puntos']

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'CustomerId', 'Apellido', 'CreditScore', 'Pais', 'Genero',
#        'Edad', 'Estadia', 'Balance', '#Prod', 'TarjetaCredito', 'Activo',
#        'Salario', 'Salida', 'Quejas', 'Nivel_satisf', 'Tipo_tarjeta',
#        'Puntos'],
#       dtype='object')

# %%
lista=['CustomerId', 'CreditScore', 
       'Edad', 'Estadia', 'Balance', '#Prod', 'TarjetaCredito', 'Activo',
       'Salario', 'Salida', 'Quejas', 'Nivel_satisf', 
       'Puntos']
for i in lista:
    plt.figure(figsize=(8, 3))
    plt.boxplot(df[i], patch_artist=True, notch=True, boxprops=dict(facecolor='lightblue', color='blue'), vert=False)
    plt.title(f'Boxplot de {i}', fontsize=16)
    plt.show()
