# %%
import pandas as pd
import matplotlib.pyplot as plt  # Librería para crear gráficos
import numpy as np  # Librería para generar datos numéricos, aquí la usamos para generar datos aleatorios

# %%
df=pd.read_csv('https://raw.githubusercontent.com/Dannap7337/Pato/main/Base_limpiaclase.csv')
df=df.drop(columns=['Unnamed: 0'])
df
# Out:
#       CustomerId   Apellido  CreditScore      Pais  Genero  Edad  Estadia  \
# 0       15647311       Hill          608    España   Mujer    41        1
# 1       15574012        Chu          645    España  Hombre    44        8
# 2       15592531   Bartlett          822   Francia  Hombre    50        7
# 3       15656148     Obinna          376  Alemania   Mujer    29        4
# 4       15792365         He          501   Francia  Hombre    44        4
# ...          ...        ...          ...       ...     ...   ...      ...
# 6659    15677538    Nwokike          569   Francia  Hombre    38        7
# 6660    15766575  Larionova          612  Alemania   Mujer    62        8
# 6661    15707602    Macleod          539   Francia   Mujer    47        2
# 6662    15733229  Rodriguez          638    España   Mujer    34        7
# 6663    15703923    Cameron          744  Alemania  Hombre    41        7
#
#         Balance  #Prod  TarjetaCredito  Activo    Salario  Salida  Quejas  \
# ...

# %%
df.columns
# Out:
# Index(['CustomerId', 'Apellido', 'CreditScore', 'Pais', 'Genero', 'Edad',
#        'Estadia', 'Balance', '#Prod', 'TarjetaCredito', 'Activo', 'Salario',
#        'Salida', 'Quejas', 'Nivel_satisf', 'Tipo_tarjeta', 'Puntos'],
#       dtype='object')

# %% [markdown]
# # Gráfico de Barras (Bar Plot) en Matplotlib
#
# Un gráfico de barras se utiliza para visualizar distribuciones de variables categóricas. A continuación se describe cómo crear un gráfico de barras y las diferentes características que puedes modificar en Matplotlib.
#
# ## Características Modificables:
#
# 1. **Datos de entrada**: La variable categórica que se representará.
# 2. **Tamaño de la figura**: Controla el tamaño del gráfico.
# 3. **Colores de las barras**: Se puede especificar el color de las barras individualmente o de forma global.
# 4. **Estilo de las barras**: Puedes personalizar el borde de las barras.
# 5. **Rotación de etiquetas**: Para hacer más legible el gráfico si las etiquetas son largas.
# 6. **Etiquetas del gráfico**: Títulos, etiquetas de los ejes y leyendas.
# 7. **Ancho de las barras**: Controla qué tan anchas o delgadas son las barras.
# 8. **Rejilla**: Añade o elimina la rejilla en el gráfico.

# %% [markdown]
# ### Desglose de Parámetros de `plt.grid()`
#
# - **`True`**:
#   Indica que se debe mostrar la rejilla. Si se establece en `False`, la rejilla no se mostrará.
#
# - **`which='both'`**:
#   Especifica qué líneas de rejilla se deben mostrar. Puede tomar los siguientes valores:
#   - `'major'`: Solo líneas de rejilla para marcas principales.
#   - `'minor'`: Solo líneas de rejilla para marcas secundarias.
#   - `'both'`: Muestra ambas, las líneas de rejilla para marcas principales y secundarias.
#
# - **`axis='y'`**:
#   Define qué eje se verá afectado por la rejilla. Puede ser:
#   - `'x'`: Rejilla solo en el eje X.
#   - `'y'`: Rejilla solo en el eje Y.
#   - `'both'`: Rejilla en ambos ejes.
#
# - **`linestyle='--'`**:
#   Especifica el estilo de las líneas de la rejilla. Los estilos pueden ser:
#   - `'-'`: Línea sólida (por defecto).
#   - `'--'`: Línea discontinua.
#   - `':'`: Línea punteada.
#   - `'-.'`: Línea de punto y raya.
#
#   En este caso, se utiliza una línea discontinua.
#
# - **`linewidth=0.7`**:
#   Controla el grosor de las líneas de la rejilla. Un valor más alto hace que las líneas sean más gruesas, mientras que un valor más bajo las hace más delgadas. El valor por defecto es `1.0`.
#
# - **`alpha=0.7`**:
#   Define la opacidad de las líneas de la rejilla. El rango va de `0` (totalmente transparente) a `1` (totalmente opaco). Un valor de `0.7` significa que las líneas serán semi-transparentes.

# %% [markdown]
# ### Desglose de Parámetros de `plt.xticks()`
#
# - **`rotation=45`**:
#   Este parámetro especifica el ángulo de rotación de las etiquetas del eje X. Un valor de `45` grados hace que las etiquetas se inclinen, lo que puede mejorar la legibilidad cuando hay muchas etiquetas o si son largas.
#
# - **`ha='right'`**:
#   Este parámetro define la alineación horizontal de las etiquetas. Puede tomar los siguientes valores:
#   - `'center'`: Alinea las etiquetas en el centro.
#   - `'right'`: Alinea las etiquetas a la derecha.
#   - `'left'`: Alinea las etiquetas a la izquierda.
#
#   En este caso, se establece en `'right'`, lo que significa que las etiquetas estarán alineadas a la derecha, lo que puede ayudar a evitar solapamientos con otras etiquetas o elementos del gráfico.

# %%
df['Edad'].value_counts()
# Out:
# Edad
# 38    327
# 37    311
# 35    306
# 36    302
# 32    295
#      ...
# 80      1
# 88      1
# 85      1
# 84      1
# 83      1
# Name: count, Length: 69, dtype: int64

# %%
plt.figure(figsize=(16, 4)) 
df['Edad'].value_counts().plot(kind='bar', color='green')
plt.title('Gráfico de Barras')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')

# Mostrar el gráfico
plt.show()

# %%
plt.figure(figsize=(15, 6)) 
df['Edad'].value_counts().plot(kind='bar', color='green')
plt.title('Gráfico de Barras')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')


# Rotar las etiquetas del eje X si es necesario
plt.xticks(rotation=45, ha='right')


# Añadir rejilla opcional
plt.grid(True, which='both', axis='y', linestyle='--', linewidth=2.7, alpha=0.5,color="black")

# Mostrar el gráfico
plt.show()

# %%
plt.figure(figsize=(15, 6))

# Ordenar las edades antes de crear el gráfico de barras
df['Edad'].value_counts().sort_index().plot(kind='bar', color='blue')

# Personalización del gráfico
plt.title('Gráfico de Barras')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')

# Rotar las etiquetas del eje X
plt.xticks(rotation=45, ha='right')

# Añadir rejilla
plt.grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, alpha=0.7)

# Mostrar el gráfico
plt.show()

# %%
df.columns
# Out:
# Index(['CustomerId', 'Apellido', 'CreditScore', 'Pais', 'Genero', 'Edad',
#        'Estadia', 'Balance', '#Prod', 'TarjetaCredito', 'Activo', 'Salario',
#        'Salida', 'Quejas', 'Nivel_satisf', 'Tipo_tarjeta', 'Puntos'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6664 entries, 0 to 6663
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerId      6664 non-null   int64
#  1   Apellido        6664 non-null   object
#  2   CreditScore     6664 non-null   int64
#  3   Pais            6664 non-null   object
#  4   Genero          6664 non-null   object
#  5   Edad            6664 non-null   int64
#  6   Estadia         6664 non-null   int64
#  7   Balance         6664 non-null   float64
#  8   #Prod           6664 non-null   int64
#  9   TarjetaCredito  6664 non-null   int64
#  10  Activo          6664 non-null   int64
#  11  Salario         6664 non-null   float64
#  12  Salida          6664 non-null   int64
#  13  Quejas          6664 non-null   int64
#  14  Nivel_satisf    6664 non-null   int64
#  15  Tipo_tarjeta    6664 non-null   object
#  16  Puntos          6664 non-null   int64
# ...

# %%
df["Quejas"].unique()
# Out:
# array([1, 0])

# %%
df.columns
# Out:
# Index(['CustomerId', 'Apellido', 'CreditScore', 'Pais', 'Genero', 'Edad',
#        'Estadia', 'Balance', '#Prod', 'TarjetaCredito', 'Activo', 'Salario',
#        'Salida', 'Quejas', 'Nivel_satisf', 'Tipo_tarjeta', 'Puntos'],
#       dtype='object')

# %%
lista=['CustomerId', 'Apellido', 'CreditScore', 'Pais', 'Genero', 'Edad',
       'Estadia', 'Balance', '#Prod', 'TarjetaCredito', 'Activo', 'Salario',
       'Salida', 'Quejas', 'Nivel_satisf', 'Tipo_tarjeta', 'Puntos']
for i in lista:
    print(f"La columna {i} tiene de valores únicos: ")
    print(df[i].unique())
    print()
# Out:
# La columna CustomerId tiene de valores únicos:
# [15647311 15574012 15592531 ... 15707602 15733229 15703923]
#
# La columna Apellido tiene de valores únicos:
# ['Hill' 'Chu' 'Bartlett' ... 'Olague' 'Bitter' 'Rodriguez']
#
# La columna CreditScore tiene de valores únicos:
# [608 645 822 376 501 528 497 476 549 726 732 669 846 756 571 574 411 591
#  553 520 722 475 490 465 556 660 829 637 550 776 788 619 725 511 614 742
#  687 684 603 735 675 738 657 519 678 665 506 493 652 635 647 524 769 515
#  773 814 710 413 623 622 582 785 605 479 628 699 828 674 656 432 625 686
#  789 584 579 663 682 793 485 650 416 754 535 716 539 706 758 586 646 800
#  721 683 667 578 512 484 510 606 850 778 730 525 601 616 521 759 516 618
#  689 620 572 695 807 592 514 567 694 547 594 673 610 585 763 712 659 634
#  771 587 681 671 531 498 651 811 707 782 799 602 703 747 750 627 731 438
#  729 642 806 744 474 559 429 680 749 734 644 626 649 805 545 543 718 840
# ...

# %%
df["Apellido"].value_counts()
# Out:
# Apellido
# Brown        22
# Shih         20
# Johnson      20
# Martin       20
# Walker       19
#              ..
# Phelps        1
# Lockett       1
# Culbreth      1
# Bowen         1
# Rodriguez     1
# Name: count, Length: 2371, dtype: int64

# %%
plt.figure(figsize=(15, 6))

# Ordenar las edades antes de crear el gráfico de barras
df['Apellido'].value_counts().sort_index().plot(kind='bar', color='pink')

# Personalización del gráfico
plt.title('Gráfico de Barras de Apellidos')
plt.xlabel('Apellido')
plt.ylabel('Frecuencia')

# Rotar las etiquetas del eje X
plt.xticks(rotation=45, ha='right')

# Añadir rejilla
plt.grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, alpha=0.7)

# Mostrar el gráfico
plt.show()

# %%
lista2=['Pais', 'Genero', 'Edad',
       'Estadia', '#Prod', 'TarjetaCredito', 'Activo',
       'Salida', 'Quejas', 'Nivel_satisf', 'Tipo_tarjeta']

# %%
for i in lista2:
    plt.figure(figsize=(6, 3))

    df[i].value_counts().sort_index().plot(kind='bar', color='blue')

    plt.title('Gráfico de Barras')
    plt.xlabel(f'{i}')
    plt.ylabel('Frecuencia')

    plt.xticks(rotation=45, ha='right')

    plt.grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, alpha=0.7)

    plt.show()

# %%
plt.figure(figsize=(15, 6))

# Obtener las 10 edades más comunes y ordenarlas
df['Apellido'].value_counts().nlargest(10).plot(kind='bar', color='black')

# Personalización del gráfico
plt.title('Top 10 Edades más Frecuentes', fontsize=16)
plt.xlabel('Edad', fontsize=12)
plt.ylabel('Frecuencia', fontsize=12)

# Rotar las etiquetas del eje X
plt.xticks(rotation=45, ha='right')

# Añadir rejilla
plt.grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, alpha=0.7)

# Mostrar el gráfico
plt.show()

# %%
plt.figure(figsize=(15, 6))

# Obtener las 10 edades menos comunes y ordenarlas
df['Apellido'].value_counts().nsmallest(10).plot(kind='bar', color='black')

# Personalización del gráfico
plt.title('Top 10 Edades más Frecuentes', fontsize=16)
plt.xlabel('Edad', fontsize=12)
plt.ylabel('Frecuencia', fontsize=12)

# Rotar las etiquetas del eje X
plt.xticks(rotation=45, ha='right')

# Añadir rejilla
plt.grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, alpha=0.7)

# Mostrar el gráfico
plt.show()

# %%
plt.figure(figsize=(15, 6))

# Obtener las 10 edades más comunes y ordenarlas
df['Edad'].value_counts().nlargest(5).plot(kind='bar', color='pink')

# Personalización del gráfico
plt.title('Top 10 Edades más Frecuentes', fontsize=16)
plt.xlabel('Edad', fontsize=12)
plt.ylabel('Frecuencia', fontsize=12)

# Rotar las etiquetas del eje X
plt.xticks(rotation=45, ha='right')

# Añadir rejilla
plt.grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, alpha=0.7)

# Mostrar el gráfico
plt.show()

# %%
plt.figure(figsize=(15, 6))

# Obtener las 10 edades más comunes y ordenarlas
df['Edad'].value_counts().nsmallest(5).plot(kind='barh', color='pink')

# Personalización del gráfico
plt.title('Top 10 Edades más Frecuentes', fontsize=16)
plt.xlabel('Edad', fontsize=12)
plt.ylabel('Frecuencia', fontsize=12)

# Rotar las etiquetas del eje X
plt.xticks(rotation=45, ha='right')

# Añadir rejilla
plt.grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, alpha=0.7)

# Mostrar el gráfico
plt.show()

# %%
# Obtener las 10 edades más comunes y ordenarlas
df['Edad'].value_counts().nlargest(10).plot(kind='barh', color='green')

# Personalización del gráfico
plt.title('Top 10 Edades más Frecuentes', fontsize=16)
plt.xlabel('Edad', fontsize=12)
plt.ylabel('Frecuencia', fontsize=12)

# Rotar las etiquetas del eje X
plt.xticks(rotation=45, ha='right')

# Añadir rejilla
plt.grid(True, which='both', axis='y', linestyle='--', linewidth=0.7, alpha=0.7)

# Mostrar el gráfico
plt.show()

# %%
plt.figure(figsize=(15, 6))

# Obtener las 10 edades más comunes (ordenadas por frecuencia de mayor a menor)
df['Edad'].value_counts().nlargest(10).plot(kind='barh', color='darkblue')

# Personalización del gráfico
plt.title('Top 10 Edades más Frecuentes', fontsize=16)
plt.xlabel('Frecuencia', fontsize=12)
plt.ylabel('Edad', fontsize=12)

# Añadir rejilla
plt.grid(True, which='both', axis='x', linestyle='--', linewidth=0.7, alpha=0.7)

# Invertir el eje Y para que la barra más alta esté en la parte superior
plt.gca().invert_yaxis()

# Mostrar el gráfico
plt.show()

# %%
# Obtener las 10 edades más comunes
top_10_edades = df['Edad'].value_counts().nlargest(10)

# Definir una lista de colores para las barras
colors = plt.cm.viridis(np.linspace(0, 1, len(top_10_edades)))

# Crear el gráfico de barras horizontal con colores múltiples
top_10_edades.plot(kind='barh', color=colors)

# Personalización del gráfico
plt.title('Top 10 Edades más Frecuentes', fontsize=16)
plt.xlabel('Frecuencia', fontsize=12)
plt.ylabel('Edad', fontsize=12)

# Añadir rejilla
plt.grid(True, which='both', axis='x', linestyle='--', linewidth=0.7, alpha=0.7)

# Invertir el eje Y para que la barra más alta esté en la parte superior
plt.gca().invert_yaxis()

# Mostrar el gráfico
plt.show()

# %%
#Top 10 apellidos
top_10_apellido = df['Apellido'].value_counts().nlargest(10)
# Definir una lista de colores para las barras
colors = plt.cm.inferno(np.linspace(0, 1, len(top_10_apellido)))
# Crear el gráfico de barras horizontal con colores múltiples
top_10_apellido.plot(kind='barh', color=colors)
# Personalización del gráfico
plt.title('Top 10 Apellidos más Frecuentes', fontsize=16)
plt.xlabel('Frecuencia', fontsize=12)
# Añadir rejilla
plt.grid(True, which='both', axis='x', linestyle='--', linewidth=0.7, alpha=0.7)
# Invertir el eje Y para que la barra más alta esté en la parte superior
plt.gca().invert_yaxis()
# Mostrar el gráfico
plt.show()

# %% [markdown]
# # Paletas de Colores en Matplotlib
#
# ## Perceptualmente Uniformes:
# - **viridis**
# - **plasma**
# - **inferno**
# - **magma**
# - **cividis**
#
# ## Secuenciales:
# - **Blues**
# - **BuGn**
# - **BuPu**
# - **GnBu**
# - **Greens**
# - **Greys**
# - **Oranges**
# - **OrRd**
# - **PuBu**
# - **PuRd**
# - **Purples**
# - **Reds**
# - **YlGn**
# - **YlOrRd**
#
# ## Divergentes:
# - **BrBG**
# - **PiYG**
# - **PRGn**
# - **PuOr**
# - **RdBu**
# - **RdGy**
# - **RdYlBu**
# - **Spectral**
#
# ## Categóricas (para gráficos con categorías específicas):
# - **tab10**
# - **tab20**
# - **Set1**
# - **Set2**
# - **Pastel1**
# - **Pastel2**
# - **Accent**

# %%
# Obtener las 10 edades más comunes
top_10_edades = df['Edad'].value_counts().nlargest(10)

# Definir una lista de colores para las barras
colors = plt.cm.inferno(np.linspace(0, 1, len(top_10_edades)))

# Crear el gráfico de barras horizontal con colores múltiples
ax = top_10_edades.plot(kind='barh', color=colors)

# Añadir etiquetas al final de cada barra
for index, value in enumerate(top_10_edades):
    ax.text(value, index, str(value), va='center')  # va='center' alinea verticalmente

# Personalización del gráfico
plt.title('Top 10 Edades más Frecuentes', fontsize=16)
plt.xlabel('Frecuencia', fontsize=12)
plt.ylabel('Edad', fontsize=12)

# Añadir rejilla
plt.grid(True, which='both', axis='x', linestyle='--', linewidth=0.7, alpha=0.7)

# Invertir el eje Y para que la barra más alta esté en la parte superior
plt.gca().invert_yaxis()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Desglose del Comando `ax.text()`
#
# - **`ax.text(value, index, str(value), va='center')`**:
#   - **`value`**: Posición en el eje X donde se coloca la etiqueta (frecuencia).
#   - **`index`**: Posición en el eje Y (la edad).
#   - **`str(value)`**: Convierte el valor a cadena para mostrarlo como texto.
#   - **`va='center'`**: Alinea verticalmente el texto al centro de la barra.
