# %%
import pandas as pd
import matplotlib.pyplot as plt  # Librería para crear gráficos
import numpy as np  # Librería para generar datos numéricos, aquí la usamos para generar datos aleatorios
import seaborn as sns

# %%
df=pd.read_csv('https://raw.githubusercontent.com/Dannap7337/Pato/main/Base_limpiaclase.csv')
df=df.drop(columns=['Unnamed: 0'])
df
# Out:
#       CustomerId   Apellido  CreditScore      Pais  Genero  Edad  Estadia  \
# 0       15647311       Hill          608    España   Mujer    41        1
# 1       15574012        Chu          645    España  Hombre    44        8
# 2       15592531   Bartlett          822   Francia  Hombre    50        7
# 3       15656148     Obinna          376  Alemania   Mujer    29        4
# 4       15792365         He          501   Francia  Hombre    44        4
# ...          ...        ...          ...       ...     ...   ...      ...
# 6659    15677538    Nwokike          569   Francia  Hombre    38        7
# 6660    15766575  Larionova          612  Alemania   Mujer    62        8
# 6661    15707602    Macleod          539   Francia   Mujer    47        2
# 6662    15733229  Rodriguez          638    España   Mujer    34        7
# 6663    15703923    Cameron          744  Alemania  Hombre    41        7
#
#         Balance  #Prod  TarjetaCredito  Activo    Salario  Salida  Quejas  \
# ...

# %%
df['Estadia'].unique()
# Out:
# array([ 1,  8,  7,  4,  6,  3, 10,  5,  9,  2,  0])

# %%
df.columns
# Out:
# Index(['CustomerId', 'Apellido', 'CreditScore', 'Pais', 'Genero', 'Edad',
#        'Estadia', 'Balance', '#Prod', 'TarjetaCredito', 'Activo', 'Salario',
#        'Salida', 'Quejas', 'Nivel_satisf', 'Tipo_tarjeta', 'Puntos'],
#       dtype='object')

# %% [markdown]
# ## Gráfico de distribución (KDE Plot)
# Este gráfico muestra una estimación de la densidad de una variable continua, lo que ayuda a visualizar la distribución de los datos de manera más suave.

# %%
# KDE para Balance
plt.figure(figsize=(10,4))
sns.kdeplot(df['Balance'], fill=True,color="red")
plt.title("Gráfica de densidad de Balance")
sns.set_style("whitegrid")
plt.show()

# %%
# Crear figura y subplots (2 filas, 2 columnas)
fig, axes = plt.subplots(2, 2, figsize=(6, 4))

# KDE para Balance
sns.kdeplot(df['Balance'], fill=True, ax=axes[0, 0])
axes[0, 0].set_title('Distribución de Balance')

# KDE para Salario
sns.kdeplot(df['Salario'], fill=True, ax=axes[0, 1], color="red")
axes[0, 1].set_title('Distribución de Salario')

# KDE para CreditScore
sns.kdeplot(df['CreditScore'], fill=True, ax=axes[1, 0],color="brown")
axes[1, 0].set_title('Distribución de CreditScore')

# KDE para Edad
sns.kdeplot(df['Edad'], fill=True, ax=axes[1, 1],color="orange")
axes[1, 1].set_title('Distribución de Edad')

# Ajustar el layout para evitar superposición de títulos y etiquetas
plt.tight_layout()

# Mostrar gráfico
plt.show()

# %% [markdown]
# ## Gráficos de Pastel (Pie Charts)
#
# Los gráficos de pastel son útiles para visualizar la distribución de datos categóricos en proporciones. Cada "porción" del pastel representa una categoría, y el tamaño de la porción es proporcional a la frecuencia o cantidad de esa categoría.

# %%
# Contar la cantidad de clientes por género
gender_counts = df['Genero'].value_counts()

# Gráfico de pastel
plt.figure(figsize=(6,6))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=90,
         colors=['skyblue', 'lightgreen'])
plt.title('Distribución por Género')
plt.show()

# %%
# Contar la cantidad de clientes por país
pais_counts = df['Pais'].value_counts()

# Gráfico de pastel
plt.figure(figsize=(6,6))
plt.pie(pais_counts, labels=pais_counts.index, autopct='%1.1f%%', startangle=90, colors=['lightcoral', 'skyblue', 'lightgreen', 'yellow'])
plt.title('Distribución por País')
plt.show()

# %%
# Contar la cantidad de clientes por tipo de tarjeta
card_type_counts = df['Tipo_tarjeta'].value_counts()

# Gráfico de pastel
plt.figure(figsize=(5,5))
plt.pie(card_type_counts, labels=card_type_counts.index, autopct='%1.1f%%', startangle=90, colors=['purple', 'orange', 'green', 'blue'])
plt.title('Distribución por Tipo de Tarjeta')
plt.show()

# %%
df.columns
# Out:
# Index(['CustomerId', 'Apellido', 'CreditScore', 'Pais', 'Genero', 'Edad',
#        'Estadia', 'Balance', '#Prod', 'TarjetaCredito', 'Activo', 'Salario',
#        'Salida', 'Quejas', 'Nivel_satisf', 'Tipo_tarjeta', 'Puntos'],
#       dtype='object')

# %%
# Contar la cantidad de clientes por tipo de tarjeta
card_type_counts = df['Nivel_satisf'].value_counts()

# Gráfico de pastel
plt.figure(figsize=(5,5))
plt.pie(card_type_counts, labels=card_type_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribución por Nivel de satisfacción')
plt.show()

# %% [markdown]
# ## Gráficos de Violín (Violin Plots)
#
# El gráfico de violín es una combinación entre un boxplot y un gráfico de densidad kernel (KDE). Permite visualizar la distribución de una variable continua a través de varias categorías, mostrando tanto la forma de la distribución como su dispersión y densidad. A diferencia de un boxplot tradicional, el gráfico de violín muestra una mayor cantidad de información al incluir la estimación de la densidad en ambos lados de la categoría.

# %%
# Gráfico de violín para CreditScore por Tipo de Tarjeta
sns.violinplot(x='CreditScore', data=df)

# Mostrar gráfico
plt.title('Distribución de CreditScore')
plt.show()

# %%
df.columns
# Out:
# Index(['CustomerId', 'Apellido', 'CreditScore', 'Pais', 'Genero', 'Edad',
#        'Estadia', 'Balance', '#Prod', 'TarjetaCredito', 'Activo', 'Salario',
#        'Salida', 'Quejas', 'Nivel_satisf', 'Tipo_tarjeta', 'Puntos'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6664 entries, 0 to 6663
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerId      6664 non-null   int64
#  1   Apellido        6664 non-null   object
#  2   CreditScore     6664 non-null   int64
#  3   Pais            6664 non-null   object
#  4   Genero          6664 non-null   object
#  5   Edad            6664 non-null   int64
#  6   Estadia         6664 non-null   int64
#  7   Balance         6664 non-null   float64
#  8   #Prod           6664 non-null   int64
#  9   TarjetaCredito  6664 non-null   int64
#  10  Activo          6664 non-null   int64
#  11  Salario         6664 non-null   float64
#  12  Salida          6664 non-null   int64
#  13  Quejas          6664 non-null   int64
#  14  Nivel_satisf    6664 non-null   int64
#  15  Tipo_tarjeta    6664 non-null   object
#  16  Puntos          6664 non-null   int64
# ...

# %%
colu=[ 'CreditScore', 'Edad',
       'Estadia', 'Balance', '#Prod', 'TarjetaCredito', 'Activo', 'Salario',
       'Salida', 'Quejas', 'Nivel_satisf', 'Puntos']

# %%
for i in colu:
    # Gráfico de violín para CreditScore por Tipo de Tarjeta
    sns.violinplot(y=i, data=df)

    # Mostrar gráfico
    plt.title(f'Distribución de {i}')
    plt.show()

# %%
# Gráfico de violín para CreditScore por Tipo de Tarjeta
sns.violinplot(y='Edad', data=df)

# Mostrar gráfico
plt.title('Distribución de edad')
plt.show()

# %% [markdown]
# ## Gráficos de correlación de dos variables

# %% [markdown]
# ## Heatmap de Correlaciones
#
# El heatmap o mapa de calor es una representación gráfica de una matriz de datos donde los valores se representan mediante variaciones de color. En este caso, podemos usar un heatmap para visualizar la matriz de correlación entre las variables numéricas en nuestro dataset. Esto nos permite identificar rápidamente qué variables están más relacionadas entre sí.
#
# ### 1. Heatmap de la Matriz de Correlación
#
# Este gráfico muestra la correlación entre las variables numéricas en el dataset del churn bancario. Los valores cercanos a 1 indican una alta correlación positiva, mientras que los valores cercanos a -1 indican una alta correlación negativa.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6664 entries, 0 to 6663
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerId      6664 non-null   int64
#  1   Apellido        6664 non-null   object
#  2   CreditScore     6664 non-null   int64
#  3   Pais            6664 non-null   object
#  4   Genero          6664 non-null   object
#  5   Edad            6664 non-null   int64
#  6   Estadia         6664 non-null   int64
#  7   Balance         6664 non-null   float64
#  8   #Prod           6664 non-null   int64
#  9   TarjetaCredito  6664 non-null   int64
#  10  Activo          6664 non-null   int64
#  11  Salario         6664 non-null   float64
#  12  Salida          6664 non-null   int64
#  13  Quejas          6664 non-null   int64
#  14  Nivel_satisf    6664 non-null   int64
#  15  Tipo_tarjeta    6664 non-null   object
#  16  Puntos          6664 non-null   int64
# ...

# %%
# Matriz de correlación
correlation_matrix = df.corr()
#Sólo sirve con columnas numéricas
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 2
#       1 # Matriz de correlación
# ----> 2 correlation_matrix = df.corr()
#       3 #Sólo sirve con columnas numéricas
#
# File c:\Users\Jaime\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:11056, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11054 cols = data.columns
#   11055 idx = cols.copy()
# > 11056 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11058 if method == "pearson":
#   11059     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\Jaime\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:1998, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1996 if dtype is not None:
#    1997     dtype = np.dtype(dtype)
# ...

# %%
# Seleccionar solo las columnas numéricas
df_numeric = df[['CreditScore', 'Edad', 'Estadia', 'Balance', '#Prod', 'TarjetaCredito', 
                 'Activo', 'Salario', 'Salida', 'Quejas', 'Nivel_satisf', 'Puntos']]
# Calcular la matriz de correlación
correlation_matrix = df_numeric.corr()
correlation_matrix
# Out:
#                 CreditScore      Edad   Estadia   Balance     #Prod  \
# CreditScore        1.000000 -0.008581 -0.005284 -0.013641  0.016507
# Edad              -0.008581  1.000000 -0.004806  0.024727 -0.036999
# Estadia           -0.005284 -0.004806  1.000000 -0.011766 -0.001400
# Balance           -0.013641  0.024727 -0.011766  1.000000 -0.301457
# #Prod              0.016507 -0.036999 -0.001400 -0.301457  1.000000
# TarjetaCredito    -0.010202 -0.017081  0.027893 -0.015301 -0.007437
# Activo             0.027002  0.089547 -0.039128 -0.001227  0.000725
# Salario            0.013137 -0.004129 -0.000077  0.016706  0.013209
# Salida            -0.025368  0.283662 -0.020160  0.114853 -0.052366
# Quejas            -0.025504  0.282624 -0.019635  0.114546 -0.052053
# Nivel_satisf      -0.007827  0.004434  0.004588 -0.000668 -0.026012
# Puntos            -0.002420 -0.002172 -0.013700  0.018640 -0.016550
#
#                 TarjetaCredito    Activo   Salario    Salida    Quejas  \
# ...

# %%
plt.figure(figsize=(10,10))
# Gráfico de calor
sns.heatmap(correlation_matrix, annot=True, cmap='inferno')
# Mostrar gráfico
plt.show()

# %%
df['Genero'].unique()
# Out:
# array(['Mujer', 'Hombre'], dtype=object)

# %% [markdown]
# Si por ejemplo se requiere saber si el genero influencia, se pueden convertir variables categóricas a variables numéricas

# %%
df2=df.copy()

# %%
# Convertir la columna 'Genero' a valores numéricos
df2['Genero'] = df2['Genero'].map({'Hombre': 2, 'Mujer': 1})
df2['Pais'] = df2['Pais'].map({'España': 1, 'Francia': 2,'Alemania':3})
df2['Tipo_tarjeta'] = df2['Tipo_tarjeta'].map({'DIAMOND': 1, 'SILVER': 2,'GOLD':3,'PLATINUM':4})
df2
# Out:
#       CustomerId   Apellido  CreditScore  Pais  Genero  Edad  Estadia  \
# 0       15647311       Hill          608     1       1    41        1
# 1       15574012        Chu          645     1       2    44        8
# 2       15592531   Bartlett          822     2       2    50        7
# 3       15656148     Obinna          376     3       1    29        4
# 4       15792365         He          501     2       2    44        4
# ...          ...        ...          ...   ...     ...   ...      ...
# 6659    15677538    Nwokike          569     2       2    38        7
# 6660    15766575  Larionova          612     3       1    62        8
# 6661    15707602    Macleod          539     2       1    47        2
# 6662    15733229  Rodriguez          638     1       1    34        7
# 6663    15703923    Cameron          744     3       2    41        7
#
#         Balance  #Prod  TarjetaCredito  Activo    Salario  Salida  Quejas  \
# ...

# %%
# Seleccionar solo las columnas numéricas
df2_numeric = df2[['Genero','Pais','Tipo_tarjeta','CreditScore', 'Edad', 'Estadia', 
                   'Balance', '#Prod', 'TarjetaCredito', 
                 'Activo', 'Salario', 'Salida', 'Quejas', 'Nivel_satisf', 'Puntos']]
# Calcular la matriz de correlación
correlation_matrix2 = df2_numeric.corr()
correlation_matrix2
# Out:
#                   Genero      Pais  Tipo_tarjeta  CreditScore      Edad  \
# Genero          1.000000 -0.032406      0.011668     0.002873 -0.034024
# Pais           -0.032406  1.000000      0.011338    -0.009196  0.037737
# Tipo_tarjeta    0.011668  0.011338      1.000000    -0.006000 -0.008883
# CreditScore     0.002873 -0.009196     -0.006000     1.000000 -0.008581
# Edad           -0.034024  0.037737     -0.008883    -0.008581  1.000000
# Estadia         0.029125 -0.009818      0.004826    -0.005284 -0.004806
# Balance         0.000585  0.328906     -0.000488    -0.013641  0.024727
# #Prod          -0.020703 -0.015437      0.017187     0.016507 -0.036999
# TarjetaCredito  0.003255  0.016469     -0.016072    -0.010202 -0.017081
# Activo          0.025545 -0.025057      0.015770     0.027002  0.089547
# Salario        -0.002367 -0.001033      0.018143     0.013137 -0.004129
# Salida         -0.102563  0.132498      0.000826    -0.025368  0.283662
# ...

# %%
plt.figure(figsize=(15,10))
# Gráfico de calor con rango limitado
sns.heatmap(correlation_matrix2, annot=True, cmap='YlGnBu', vmin=-0.1, vmax=0.4)

# Mostrar gráfico
plt.show()

# %% [markdown]
# ## Pairplot
# El pairplot se utiliza para visualizar todas las combinaciones de pares de variables en un DataFrame. Es especialmente útil para explorar relaciones entre múltiples variables numéricas y ver cómo se distribuyen en función de una variable categórica.
#
# Uso: Visualizar relaciones entre varias variables numéricas y categóricas.
# Características:
# Muestra un gráfico de dispersión (scatter plot) para cada par de variables.
# En la diagonal, generalmente muestra histogramas o gráficas de densidad para cada variable.

# %%
# Pairplot para visualizar la relación entre las variables numéricas
sns.pairplot(df2_numeric)
# Mostrar gráfico
plt.title('Pairplot de Variables Numéricas')
plt.show()

# %% [markdown]
# ## Jointplot
# El jointplot se utiliza para mostrar la relación entre dos variables y también su distribución marginal. Es útil para ver cómo se correlacionan dos variables numéricas y también proporciona histogramas de las distribuciones de cada variable en los ejes.
#
# Uso: Visualizar la relación entre dos variables y sus distribuciones.
# Características:
# Muestra un gráfico de dispersión entre dos variables.
# Incluye histogramas o gráficos de densidad en los márgenes.

# %%
# Gráfico conjunto de Salario y Balance
sns.jointplot(data=df, x='Salario', y='Balance', hue='Pais', kind='scatter')
plt.title('Jointplot de Salario y Balance')
plt.show()

# %% [markdown]
# ## Displot
# El displot es una función que combina histogramas y gráficos de densidad. Es útil para visualizar la distribución de una sola variable numérica y se puede usar con la opción de hue para mostrar diferentes categorías.
#
# Uso: Visualizar la distribución de una variable.
# Características:
# Puede mostrar un histograma y/o un gráfico de densidad.
# Permite dividir el gráfico por categorías usando col o row.
# Tiene la opción de ajustar el número de bins y cambiar la apariencia.

# %%
# Gráfico de distribución para Salario
sns.displot(data=df, x='Salario', hue='Genero', kde=True, bins=30)

# Mostrar el gráfico
plt.title('Distribución del Salario por Género')
plt.show()

# %% [markdown]
# # Gráfica de dispersión

# %%
df.columns
# Out:
# Index(['CustomerId', 'Apellido', 'CreditScore', 'Pais', 'Genero', 'Edad',
#        'Estadia', 'Balance', '#Prod', 'TarjetaCredito', 'Activo', 'Salario',
#        'Salida', 'Quejas', 'Nivel_satisf', 'Tipo_tarjeta', 'Puntos'],
#       dtype='object')

# %%
sns.scatterplot(x='CreditScore',y='Edad',data=df)
plt.show()
