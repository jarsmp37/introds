# %% [markdown]
# About Dataset
#
# RowNumber—corresponds to the record (row) number and has no effect on the output.
#
# CustomerId—contains random values and has no effect on customer leaving the bank.
#
# Surname—the surname of a customer has no impact on their decision to leave the bank.
#
# CreditScore—can have an effect on customer churn, since a customer with a higher credit score is less likely to leave the bank.
#
# Geography—a customer’s location can affect their decision to leave the bank.
#
# Gender—it’s interesting to explore whether gender plays a role in a customer leaving the bank.
#
# Age—this is certainly relevant, since older customers are less likely to leave their bank than younger ones.
#
# Tenure—refers to the number of years that the customer has been a client of the bank. Normally, older clients are more loyal and less likely to leave a bank.
#
# Balance—also a very good indicator of customer churn, as people with a higher balance in their accounts are less likely to leave the bank compared to those with lower balances.
#
# NumOfProducts—refers to the number of products that a customer has purchased through the bank.
#
# HasCrCard—denotes whether or not a customer has a credit card. This column is also relevant, since people with a credit card are less likely to leave the bank.
#
# IsActiveMember—active customers are less likely to leave the bank.
#
# EstimatedSalary—as with balance, people with lower salaries are more likely to leave the bank compared to those with higher salaries.
#
# Exited—whether or not the customer left the bank.
#
# Complain—customer has complaint or not.
#
# Satisfaction Score—Score provided by the customer for their complaint resolution.
#
# Card Type—type of card hold by the customer.
#
# Points Earned—the points earned by the customer for using credit card.
#
# Acknowledgements
#
# As we know, it is much more expensive to sign in a new client than keeping an existing one.
#
# It is advantageous for banks to know what leads a client towards the decision to leave the company.
#
# Churn prevention allows companies to develop loyalty programs and retention campaigns to keep as many customers as possible.

# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/jarsmp37/introds/main/Churn_Bank.csv')
df
# Out:
#       RowNumber  CustomerId   Surname CreditScore      Geography  Gender  \
# 0           1.0  15634602.0  Hargrave         619         France  Female
# 1           2.0  15647311.0      Hill         608          Spain  Female
# 2           3.0  15619304.0      Onio         502         France  Female
# 3           4.0  15701354.0      Boni         699         France  Female
# 4           5.0  15737888.0  Mitchell         850          Spain  Female
# ...         ...         ...       ...         ...            ...     ...
# 12200    7026.0  15711446.0  Sinclair         569          Spain  Female
# 12201    1272.0  15793854.0     Ahmed         723         France    Male
# 12202    4942.0  15715047.0    Joshua         640  invalid_value    Male
# 12203    8299.0  15605534.0  Turnbull         644        Germany  Female
# 12204    1689.0  15804610.0    Valdez         601         France  Female
#
#         Age Tenure    Balance NumOfProducts HasCrCard IsActiveMember  \
# ...

# %% [markdown]
# # Visualizar primeros renglones

# %%
df.head()
# Out:
#   RowNumber  CustomerId   Surname CreditScore Geography  Gender   Age Tenure  \
# 0       1.0  15634602.0  Hargrave         619    France  Female   NaN      2
# 1       2.0  15647311.0      Hill         608     Spain  Female  41.0      1
# 2       3.0  15619304.0      Onio         502    France  Female  42.0      8
# 3       4.0  15701354.0      Boni         699    France  Female  39.0      1
# 4       5.0  15737888.0  Mitchell         850     Spain  Female   NaN      2
#
#      Balance NumOfProducts HasCrCard IsActiveMember EstimatedSalary Exited  \
# 0        0.0           1.0         1              1       101348.88      1
# 1   83807.86           1.0         0              1       112542.58      0
# 2   159660.8           3.0         1              0       113931.57    NaN
# 3        0.0           2.0         0              0        93826.63      0
# 4  125510.82           1.0         1              1   invalid_value      0
#
# ...

# %% [markdown]
# # Visualizar último renglones

# %%
df.tail()
# Out:
#       RowNumber  CustomerId   Surname CreditScore      Geography  Gender  \
# 12200    7026.0  15711446.0  Sinclair         569          Spain  Female
# 12201    1272.0  15793854.0     Ahmed         723         France    Male
# 12202    4942.0  15715047.0    Joshua         640  invalid_value    Male
# 12203    8299.0  15605534.0  Turnbull         644        Germany  Female
# 12204    1689.0  15804610.0    Valdez         601         France  Female
#
#         Age Tenure    Balance NumOfProducts HasCrCard IsActiveMember  \
# 12200  51.0      3        0.0           3.0         1              0
# 12201  42.0      2   99095.73           1.0         1              1
# 12202  43.0      9  172478.15           1.0         1              0
# 12203  51.0      4   95560.04           1.0         0              0
# 12204  41.0      1        0.0           2.0         0              1
#
#       EstimatedSalary Exited Complain Satisfaction Score Card Type  \
# ...

# %% [markdown]
# # Visualizar columnas y filas del dataframe

# %%
df.shape
# Out:
# (12205, 18)

# %% [markdown]
# # Ver el nombre de mis columnas

# %%
lista=df.columns
lista
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited', 'Complain',
#        'Satisfaction Score', 'Card Type', 'Point Earned'],
#       dtype='object')

# %% [markdown]
# Visualizar que valores únicos vienen en una columna

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male', nan, 'invalid_value'], dtype=object)

# %%
df['Tenure'].unique()
# Out:
# array(['2', '1', '8', '7', '4', '6', '3', '10', '5', '9', '0', nan,
#        'invalid_value'], dtype=object)

# %%
df['Card Type'].unique()
# Out:
# array(['DIAMOND', 'GOLD', 'SILVER', 'PLATINUM', 'invalid_value', nan],
#       dtype=object)

# %% [markdown]
# Visualizar cuantos valores únicos hay por columna

# %%
df.shape
# Out:
# (12205, 18)

# %%
df['CustomerId'].nunique()
# Out:
# 9756

# %%
df['Balance'].nunique()
# Out:
# 6235

# %%
df
# Out:
#       RowNumber  CustomerId   Surname CreditScore      Geography  Gender  \
# 0           1.0  15634602.0  Hargrave         619         France  Female
# 1           2.0  15647311.0      Hill         608          Spain  Female
# 2           3.0  15619304.0      Onio         502         France  Female
# 3           4.0  15701354.0      Boni         699         France  Female
# 4           5.0  15737888.0  Mitchell         850          Spain  Female
# ...         ...         ...       ...         ...            ...     ...
# 12200    7026.0  15711446.0  Sinclair         569          Spain  Female
# 12201    1272.0  15793854.0     Ahmed         723         France    Male
# 12202    4942.0  15715047.0    Joshua         640  invalid_value    Male
# 12203    8299.0  15605534.0  Turnbull         644        Germany  Female
# 12204    1689.0  15804610.0    Valdez         601         France  Female
#
#         Age Tenure    Balance NumOfProducts HasCrCard IsActiveMember  \
# ...

# %%
df['Card Type'].nunique()
# Out:
# 5

# %%
df['Geography'].nunique()
# Out:
# 4

# %% [markdown]
# Contar cuantos valores hay de cada valor único por columna

# %%
df['Geography'].value_counts()
# Out:
# Geography
# France           6004
# Spain            2985
# Germany          2948
# invalid_value     139
# Name: count, dtype: int64

# %%
df['Card Type'].value_counts()
# Out:
# Card Type
# PLATINUM         3003
# DIAMOND          2975
# GOLD             2967
# SILVER           2954
# invalid_value     137
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male             6526
# Female           5427
# invalid_value     116
# Name: count, dtype: int64

# %%
df['HasCrCard'].value_counts()
# Out:
# HasCrCard
# 1                8431
# 0                3492
# invalid_value     129
# Name: count, dtype: int64

# %% [markdown]
# Tipo de datos por columna

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12205 entries, 0 to 12204
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   RowNumber           12069 non-null  object
#  1   CustomerId          12050 non-null  object
#  2   Surname             12083 non-null  object
#  3   CreditScore         12080 non-null  object
#  4   Geography           12076 non-null  object
#  5   Gender              12069 non-null  object
#  6   Age                 12057 non-null  object
#  7   Tenure              12079 non-null  object
#  8   Balance             12065 non-null  object
#  9   NumOfProducts       12085 non-null  object
#  10  HasCrCard           12052 non-null  object
#  11  IsActiveMember      12076 non-null  object
#  12  EstimatedSalary     12061 non-null  object
#  13  Exited              12065 non-null  object
#  14  Complain            12060 non-null  object
# ...

# %% [markdown]
# Estadistica básica (debe haber datos numéricos tipo int)

# %%
df.describe()
# Out:
#             RowNumber     CustomerId        Surname CreditScore Geography  \
# count           12069          12050          12083       12080     12076
# unique           9778           9756           2902         461         4
# top     invalid_value  invalid_value  invalid_value         850    France
# freq              134            140            123         276      6004
#
#        Gender    Age Tenure Balance NumOfProducts HasCrCard IsActiveMember  \
# count   12069  12057  12079   12065         12085     12052          12076
# unique      3     71     12    6235             5         3              3
# top      Male   38.0      2     0.0           1.0         1              1
# freq     6526    571   1239    4300          6048      8431           6159
#
#        EstimatedSalary Exited Complain Satisfaction Score Card Type  \
# count            12061  12065    12060              12060     12036
# unique            9754      3        3                  6         5
# ...

# %% [markdown]
# # Contar valores nulos en cada columna.
#
# Los NaN (Not a Number) **Representación de datos faltantes:** En Pandas

# %%
df.isnull().sum()
# Out:
# RowNumber             136
# CustomerId            155
# Surname               122
# CreditScore           125
# Geography             129
# Gender                136
# Age                   148
# Tenure                126
# Balance               140
# NumOfProducts         120
# HasCrCard             153
# IsActiveMember        129
# EstimatedSalary       144
# Exited                140
# Complain              145
# Satisfaction Score    145
# Card Type             169
# Point Earned          126
# dtype: int64

# %% [markdown]
# # Contar filas duplicadas

# %%
df.duplicated().sum()
# Out:
# 1814
